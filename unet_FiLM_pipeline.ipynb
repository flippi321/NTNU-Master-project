# %%
# %autosave 60
# %pip install --quiet -r requirements.txt
# Out:
# Autosaving every 60 seconds
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Setup

# %%
import os
import numpy as np
import torch
import torch.optim as optim
from tqdm import tqdm
from utils.data_loader import DataLoader
from utils.metadata_loader import MetaDataLoader
from utils.data_converter import DataConverter
from utils.data_analyser import DataAnalyser
from models.unet_3d_film import FiLMUNet3D
from utils.train_eval import fit_feature_based_3D
from utils.loss_functions import ssim_loss, l1_loss, ssim_l1_loss

root_path = 'data/'

data_loader = DataLoader(root_path=root_path)
metadata_loader = MetaDataLoader()
data_converter = DataConverter()
data_analyser = DataAnalyser(root_path=root_path)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %% [markdown]
# Flush cuda memory

# %%
torch.cuda.empty_cache()

# %% [markdown]
# Common Variables

# %%
model_epochs            = 2000
snapshot_every          = 500
model_checkpoint_every  = 250

img_crop_axes = ((16, 10, 0), (17, 11, 17))

# %%
training_pairs, validation_pairs, test_pairs = data_loader.split_dataset_paths(seed=69) # Standard 70/20/10 split
print("We have", len(training_pairs), "training pairs")
print("We have", len(test_pairs), "test pairs")
# Out:
# We have 492 training pairs
# We have 106 test pairs

# %% [markdown]
# ## 3D Simple FiLM

# %% [markdown]
# ### Model Training

# %%
output_dir = "out/unets"
unet_path = f"{output_dir}/3d_unet_model_film_simple.pt"
unet = FiLMUNet3D(in_ch=1, base=32, cond_dim=2, use_simple=True)
unet_optimizer = optim.AdamW(unet.parameters(), lr=1e-4, weight_decay=1e-4, betas=(0.9, 0.95))

# %%
# Load existing model if it exists
if os.path.isfile(unet_path):
    print("Loading existing model")
    unet.load_state_dict(torch.load(unet_path))
else:
    print("No existing 3D U-Net found, starting fresh training.")
    os.makedirs(output_dir, exist_ok=True)
    
print(len(training_pairs), "training pairs")
# Out:
# No existing 3D U-Net found, starting fresh training.
# 492 training pairs

# %%
unet, unet_losses, unet_snapshots, unet_best = fit_feature_based_3D(
    model=unet,
    device=device,
    training_pairs=training_pairs,
    validation_pairs=validation_pairs,
    epochs=model_epochs,
    loss_func=ssim_l1_loss,
    metadataLoader=metadata_loader,
    dataConverter=data_converter,
    optimizer=unet_optimizer,           
    snapshot_every=snapshot_every,
    checkpoint_every=model_checkpoint_every,
    crop_axes=img_crop_axes,
)
# Out:
# Training 3D Residual U-Net:   3%|▎         | 57/2000 [04:49<2:44:38,  5.08s/it, Best loss on val 0.795657, (Iter 0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 unet, unet_losses, unet_snapshots, unet_best = fit_feature_based_3D(
#       2     model=unet,
#       3     device=device,
#       4     training_pairs=training_pairs,
#       5     validation_pairs=validation_pairs,
#       6     epochs=model_epochs,
#       7     loss_func=ssim_l1_loss,
#       8     metadataLoader=metadata_loader,
#       9     dataConverter=data_converter,
#      10     optimizer=unet_optimizer,
#      11     snapshot_every=snapshot_every,
#      12     checkpoint_every=model_checkpoint_every,
#      13     crop_axes=img_crop_axes,
#      14 )
#
# File ~/NTNU-Master-project/utils/train_eval.py:220, in fit_feature_based_3D(model, device, training_pairs, validation_pairs, epochs, loss_func, dataConverter, metadataLoader, optimizer, snapshot_every, checkpoint_every, crop_axes)
#     217 x_path, y_path = training_pairs[patient_id]
#     219 # Load full volumes as tensors
# --> 220 x_full = dataConverter.load_path_as_tensor(x_path, device)
#     221 y_full = dataConverter.load_path_as_tensor(y_path, device)
#     223 # Crop if specified
#
# File ~/NTNU-Master-project/utils/data_converter.py:36, in DataConverter.load_path_as_tensor(self, path, device)
#      32 def load_path_as_tensor(self, path: str, device = 'cuda'):
#      33     """
#      34     Function to load a NIfTI volume as a torch tensor using the data path
#      35     """
# ---> 36     data = self.load_path_as_numpy(path)
#      37     tensor = torch.tensor(data, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)  # Get correct (1, 1, D, H, W) structure
#      38     return tensor.float()
#
# File ~/NTNU-Master-project/utils/data_converter.py:17, in DataConverter.load_path_as_numpy(self, path)
#      13 """
#      14 Function to load a NIfTI volume as a numpy array using the data path
#      15 """
#      16 img = nib.load(path)
# ---> 17 data = img.get_fdata()
#      18 return data
#
# File /home/conda/lib/python3.14/site-packages/nibabel/dataobj_images.py:373, in DataobjImage.get_fdata(self, caching, dtype)
#     369         return self._fdata_cache
#     370 # Always return requested data type
#     371 # For array proxies, will attempt to confine data array to dtype
#     372 # during scaling
# --> 373 data = np.asanyarray(self._dataobj, dtype=dtype)
#     374 if caching == 'fill':
#     375     self._fdata_cache = data
#
# File /home/conda/lib/python3.14/site-packages/nibabel/arrayproxy.py:455, in ArrayProxy.__array__(self, dtype)
#     434 def __array__(self, dtype=None):
#     435     """Read data from file and apply scaling, casting to ``dtype``
#     436
#     437     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)    453         Scaled image data with type `dtype`.
#     454     """
# --> 455     arr = self._get_scaled(dtype=dtype, slicer=())
#     456     if dtype is not None:
#     457         arr = arr.astype(dtype, copy=False)
#
# File /home/conda/lib/python3.14/site-packages/nibabel/arrayproxy.py:422, in ArrayProxy._get_scaled(self, dtype, slicer)
#     420     scl_inter = scl_inter.astype(use_dtype)
#     421 # Read array and upcast as necessary for big slopes, intercepts
# --> 422 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     423 if dtype is not None:
#     424     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File /home/conda/lib/python3.14/site-packages/nibabel/arrayproxy.py:392, in ArrayProxy._get_unscaled(self, slicer)
#     388 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     389     (), self._shape, False
#     390 ):
#     391     with self._get_fileobj() as fileobj, self._lock:
# --> 392         return array_from_file(
#     393             self._shape,
#     394             self._dtype,
#     395             fileobj,
#     396             offset=self._offset,
#     397             order=self.order,
#     398             mmap=self._mmap,
#     399         )
#     400 with self._get_fileobj() as fileobj:
#     401     return fileslice(
#     402         fileobj,
#     403         slicer,
#    (...)    408         lock=self._lock,
#     409     )
#
# File /home/conda/lib/python3.14/site-packages/nibabel/volumeutils.py:464, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     462 if hasattr(infile, 'readinto'):
#     463     data_bytes = bytearray(n_bytes)
# --> 464     n_read = infile.readinto(data_bytes)
#     465     needs_copy = False
#     466 else:
#
# File /home/conda/lib/python3.14/gzip.py:365, in GzipFile.readinto(self, b)
#     363 self._check_not_closed()
#     364 self._check_read("readinto")
# --> 365 return self._buffer.readinto(b)
#
# File /home/conda/lib/python3.14/compression/_common/_streams.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /home/conda/lib/python3.14/gzip.py:578, in _GzipReader.read(self, size)
#     576 if self._decompressor.needs_input:
#     577     buf = self._fp.read(READ_BUFFER_SIZE)
# --> 578     uncompress = self._decompressor.decompress(buf, size)
#     579 else:
#     580     uncompress = self._decompressor.decompress(b"", size)
#
# KeyboardInterrupt:

# %%
for snapshot in unet_snapshots:
    print(f"Displaying snapshot from pair {snapshot['iter']}, loss: {snapshot['loss']:.4f}")
    difference = np.abs(snapshot["recon"] - snapshot["y"])
    data_analyser.display_slices([snapshot["x"], snapshot["y"], snapshot["recon"], difference], slice_labels=["HUNT 3", "HUNT 4", "U-Net Reconstruction", f"Difference ({np.mean(difference):.3f})"], slice_colors=["gray", "gray", "gray", "hot"])
# Out:
# Displaying snapshot from pair 0, loss: 0.8185
# Displaying snapshot from pair 500, loss: 0.2530
# Displaying snapshot from pair 1000, loss: 0.1815
# Displaying snapshot from pair 1500, loss: 0.0905
# Displaying snapshot from pair 1999, loss: 0.0900

# %%
# Save the final model to the /out directory
torch.save(unet_best.state_dict(), unet_path)
print(f"Model saved to {unet_path}")
# Out:
# Model saved to out/unets/3d_unet_model_film_simple.pt

# %% [markdown]
# ### Model Evaluation over Testset

# %%
output_dir = "out/unets"
unet_path = f"{output_dir}/3d_unet_model_film_simple.pt"

# Import model before testing
unet = FiLMUNet3D(in_ch=1, base=32, cond_dim=2, use_simple=True)
unet.load_state_dict(torch.load(unet_path))
print("Loaded trained model for testing.")
# Out:
# Loaded trained model for testing.

# %%
unet.eval()
avg_unet_loss = 0.0

# Estimate Accuracy over testset
for (input_path, target_path) in tqdm(test_pairs):
    # Import image from paths
    input_full, target_full = data_converter.load_path_as_tensor(input_path), data_converter.load_path_as_tensor(target_path)
    input, target = data_converter.get_volume_with_3d_change(tensor=input_full, crop_axes=img_crop_axes, remove_mode=True), data_converter.get_volume_with_3d_change(tensor=target_full, crop_axes=img_crop_axes, remove_mode=True)

    # Get user features
    cond = data_converter.get_patient_feature_vector(input_path, feature_usage).to(device=device, dtype=input.dtype)
    cond = cond.to(input.device)

    # Get Reconstructions
    unet_recon = unet(input, cond)
    target_num = target

    # calculate 3d loss
    avg_unet_loss += ssim_loss(unet_recon, target_num).item()

avg_unet_loss /= len(test_pairs)

print(f"Average U-Net 3D Loss over Test Set: {avg_unet_loss:.4f}")

# We save the model with the test loss in the filename for easy identification
test_unet_path = f"{output_dir}/3d_unet_model_film_simple_testloss_{avg_unet_loss:.4f}.pt"
torch.save(unet.state_dict(), test_unet_path)
print(f"Test model saved to {test_unet_path}")
# Out:
#   0%|          | 0/106 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[13], line 15
#      12 cond = cond.to(input.device)
#      14 # Get Reconstructions
# ---> 15 unet_recon = unet(input, cond)
#      16 target_num = target
#      18 # calculate 3d loss
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NTNU-Master-project/models/unet_3d_film.py:211, in forward(self, x, cond)
#     210 def forward(self, x, cond):
# --> 211     films = self.film_gen(cond.to(self.dev0))
#     213     # --- Encoder on GPU 0 ---
#     214     x = x.to(self.dev0)
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NTNU-Master-project/models/unet_3d_film.py:136, in Down.forward(self, x, film)
#     135 def forward(self, x, film=None):
# --> 136     skip = self.conv(x, film=film)
#     137     down = self.pool(skip)
#     138     return skip, down
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NTNU-Master-project/models/unet_3d_film.py:119, in ConvBlock.forward(self, x, film)
#     117 x = self.conv1(x)
#     118 x = self.norm1(x)
# --> 119 x = self._apply_film(x, film)
#     120 x = self.act1(x)
#     122 x = self.conv2(x)
#
# File ~/NTNU-Master-project/models/unet_3d_film.py:112, in ConvBlock._apply_film(self, x, film)
#     110 gamma, beta = film
#     111 if self.use_simple:
# --> 112     return self.film(x, gamma, beta)    # gamma/beta: [B,1]
#     113 else:
#     114     return self.film(x, gamma, beta)
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /home/conda/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NTNU-Master-project/models/unet_3d_film.py:16, in FiLMLayer.forward(self, x, gamma, beta)
#      14 gamma = gamma[:, :, None, None, None]
#      15 beta  = beta[:, :, None, None, None]
# ---> 16 return gamma * x + beta
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.40 GiB. GPU 0 has a total capacity of 39.49 GiB of which 422.56 MiB is free. Including non-PyTorch memory, this process has 39.07 GiB memory in use. Of the allocated memory 38.07 GiB is allocated by PyTorch, and 513.17 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # 3D Complex Film

# %% [markdown]
# ### Model Training

# %%
output_dir = "out/unets"
unet_path = f"{output_dir}/3d_unet_model_film_complex.pt"
unet = FiLMUNet3D(in_ch=1, base=32, cond_dim=2, use_simple=False)
unet_optimizer = optim.AdamW(unet.parameters(), lr=1e-4, weight_decay=1e-4)

# %%
# Load existing model if it exists
if os.path.isfile(unet_path):
    print("Loading existing model")
    unet.load_state_dict(torch.load(unet_path))
else:
    print("No existing 3D U-Net found, starting fresh training.")
    os.makedirs(output_dir, exist_ok=True)
    
print(len(training_pairs), "training pairs")
# Out:
# Loading existing model
# 492 training pairs

# %%
unet, unet_losses, unet_snapshots, unet_best = fit_feature_based_3D(
    model=unet,
    device=device,
    training_pairs=training_pairs,
    validation_pairs=validation_pairs,
    epochs=model_epochs,
    loss_func=ssim_loss,
    dataConverter=data_converter,
    optimizer=unet_optimizer,
    snapshot_every=snapshot_every,
    checkpoint_every=model_checkpoint_every,
    crop_axes=img_crop_axes,
    feature_usage_list=feature_usage
)
# Out:
# Training 3D Residual U-Net:   0%|          | 0/2000 [00:00<?, ?it/s]
# Training 3D Residual U-Net:  12%|█▎        | 250/2000 [04:35<25:43,  1.13it/s, Best loss on val 0.122378, (Iter 0)]

# %%
for snapshot in unet_snapshots:
    print(f"Displaying snapshot from pair {snapshot['iter']}, loss: {snapshot['loss']:.4f}")
    difference = np.abs(snapshot["recon"] - snapshot["y"])
    data_analyser.display_slices([snapshot["x"], snapshot["y"], snapshot["recon"], difference], slice_labels=["HUNT 3", "HUNT 4", "U-Net Reconstruction", f"Difference ({np.mean(difference):.3f})"], slice_colors=["gray", "gray", "gray", "hot"])
# Out:
# Displaying snapshot from pair 0, loss: 0.9945
# Displaying snapshot from pair 500, loss: 0.1439
# Displaying snapshot from pair 1000, loss: 0.1269
# Displaying snapshot from pair 1500, loss: 0.5125
# Displaying snapshot from pair 1999, loss: 0.2424

# %%
# Save the final model to the /out directory
torch.save(unet_best.state_dict(), unet_path)
print(f"Model saved to {unet_path}")
# Out:
# Model saved to out/unets/3d_unet_model_film_complex.pt

# %% [markdown]
# ### Model Evaluation over Testset

# %%
output_dir = "out/unets"
unet_path = f"{output_dir}/3d_unet_model_film_complex.pt"

# Import model before testing
unet = FiLMUNet3D(in_ch=1, base=32, cond_dim=2, use_simple=False)
unet.load_state_dict(torch.load(unet_path))
print("Loaded trained model for testing.")
# Out:
# Loaded trained model for testing.

# %%
unet.eval()
avg_unet_loss = 0.0

# Estimate Accuracy over testset
for (input_path, target_path) in tqdm(test_pairs):
    # Import image from paths
    input_full, target_full = data_converter.load_path_as_tensor(input_path), data_converter.load_path_as_tensor(target_path)
    input, target = data_converter.get_volume_with_3d_change(tensor=input_full, crop_axes=img_crop_axes, remove_mode=True), data_converter.get_volume_with_3d_change(tensor=target_full, crop_axes=img_crop_axes, remove_mode=True)

    # Get user features
    cond = data_converter.get_patient_feature_vector(input_path, feature_usage).to(device=device, dtype=input.dtype)

    # Get Reconstructions
    unet_recon = unet(input, cond)
    target_num = target

    # calculate 3d loss
    avg_unet_loss += ssim_loss(unet_recon, target_num).item()

avg_unet_loss /= len(test_pairs)

print(f"Average U-Net 3D Loss over Test Set: {avg_unet_loss:.4f}")

# We save the model with the test loss in the filename for easy identification
test_unet_path = f"{output_dir}/3d_unet_model_film_complex_testloss_{avg_unet_loss:.4f}.pt"
torch.save(unet.state_dict(), test_unet_path)
print(f"Test model saved to {test_unet_path}")
# Out:
# 100%|██████████| 106/106 [00:59<00:00,  1.78it/s]
# Average U-Net 3D Loss over Test Set: 0.1202
# Test model saved to out/unets/3d_unet_model_film_complex_testloss_0.1202.pt
